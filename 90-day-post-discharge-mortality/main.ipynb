# %%
import numpy as np
import pandas as pd
from collections import Counter

from sklearn.model_selection import train_test_split
from sklearn.model_selection import ShuffleSplit

# %%
df_pop = pd.read_csv('./data/population.csv')[['HADM_ID', 'partition']]
df_label = pd.read_csv('./data/label.csv')[['HADM_ID', 'mortality_day', 'label']]

# %%
df_pop_label = df_label.merge(df_pop).sort_values(by='HADM_ID')

# %%
df_pop_label.to_csv('input/label.csv', index=False)
df_pop_label[['HADM_ID']].rename(columns={'HADM_ID': 'ID'}).to_csv('input/pop.csv', index=False)

# %%
df_data = pd.read_pickle('./data/clinical.p')

# %%
df_ICD = pd.read_csv('./data/icd_data.csv')

# %% [markdown]
# ## Run FIDDLE - ICD

# %%
! PYTHONPATH="$PYTHONPATH:./" \
python -m FIDDLE_icd.run \
    --data_path='./output/' \
    --input_fname='./data/icd_data.csv' \
    --population='./input/pop.csv' \
    --T=4320.0 --dt=1.0 \
    --theta_1=0.01 --theta_2=0.01 --theta_freq=1
# [0]
# Out:
# Input data file: ./data/icd_data.csv
#
# Input arguments:
#     T      = 4320
#     dt     = 1.0
#     θ₁     = 0.01
#     θ₂     = 0.01
#     θ_freq = 1.0
#     k      = 3 ['min', 'max', 'mean']
# binarize = yes
#
# N = 19723
# L = 4320
#
#
# ================================================================================
# 1) Pre-filter
# ================================================================================
# Remove rows not in population
# Remove rows with t outside of [0, 4320]
# Remove rare variables (<= 0.01)
# Total variables     : 1
# Rare variables      : 0
# Remaining variables : 1
# # rows (original)   : 280540
# # rows (filtered)   : 280540
#
# ================================================================================
# 2) Transform; 3) Post-filter
# ================================================================================
#
# --------------------------------------------------------------------------------
# *) Detecting and parsing value types
# --------------------------------------------------------------------------------
# Saved as: ./output/value_types.csv
# 2020-03-13 19:33:56,600: Note: detected 112 virtual cores but NumExpr set to maximum of 64, check "NUMEXPR_MAX_THREADS" environment variable.
# 2020-03-13 19:33:56,600: Note: NumExpr detected 112 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 2020-03-13 19:33:56,600: NumExpr defaulting to 8 threads.
# /data4/tangsp/FIDDLE_experiments/90-day-post-discharge-mortality/FIDDLE_icd/steps.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_non_num_dup[var_col] = df_non_num_dup[var_col].astype(str) + ':' + df_non_num_dup[val_col].astype(str)
# /data4/tangsp/FIDDLE_experiments/90-day-post-discharge-mortality/FIDDLE_icd/steps.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_non_num_dup[val_col] = 1
#
# --------------------------------------------------------------------------------
# *) Separate time-invariant and time-dependent
# --------------------------------------------------------------------------------
# Variables (time-invariant): 20
# Variables (time-dependent): 0
# # rows    (time-invariant): 143772
# # rows    (time-dependent): 0
#
# --------------------------------------------------------------------------------
# 2-A) Transform time-invariant data
# --------------------------------------------------------------------------------
# (N × ^d) table            :	 (19723, 20)
# number of missing entries :	 250688 out of 394460 total
# Time elapsed: 0.193590 seconds
#
# Output
# s_all, binary features    :	 (19723, 31)
# Time elapsed: 1.081435 seconds
#
# --------------------------------------------------------------------------------
# 3-A) Post-filter time-invariant data
# --------------------------------------------------------------------------------
# Original       : 31
# Nearly-constant: 14
# Correlated     : 0
# Time elapsed: 1.141301 seconds
#
# Output
# s: shape=(19723, 17), density=0.428
# Total time: 1.199024 seconds

# %%
! PYTHONPATH="$PYTHONPATH:./" \
python -m FIDDLE_icd.run \
    --data_path='./output/' \
    --input_fname='./data/icd_data.csv' \
    --population='./input/pop.csv' \
    --T=4320.0 --dt=1.0 \
    --theta_1=0.01 --theta_2=0.01 --theta_freq=1
# [0,1]
# Out:
# Input data file: ./data/icd_data.csv
#
# Input arguments:
#     T      = 4320
#     dt     = 1.0
#     θ₁     = 0.01
#     θ₂     = 0.01
#     θ_freq = 1.0
#     k      = 3 ['min', 'max', 'mean']
# binarize = yes
#
# N = 19723
# L = 4320
#
#
# ================================================================================
# 1) Pre-filter
# ================================================================================
# Remove rows not in population
# Remove rows with t outside of [0, 4320]
# Remove rare variables (<= 0.01)
# Total variables     : 1
# Rare variables      : 0
# Remaining variables : 1
# # rows (original)   : 280540
# # rows (filtered)   : 280540
#
# ================================================================================
# 2) Transform; 3) Post-filter
# ================================================================================
#
# --------------------------------------------------------------------------------
# *) Detecting and parsing value types
# --------------------------------------------------------------------------------
# Saved as: ./output/value_types.csv
# 2020-03-13 19:36:08,912: Note: detected 112 virtual cores but NumExpr set to maximum of 64, check "NUMEXPR_MAX_THREADS" environment variable.
# 2020-03-13 19:36:08,912: Note: NumExpr detected 112 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 2020-03-13 19:36:08,912: NumExpr defaulting to 8 threads.
#
# --------------------------------------------------------------------------------
# *) Separate time-invariant and time-dependent
# --------------------------------------------------------------------------------
# Variables (time-invariant): 195
# Variables (time-dependent): 0
# # rows    (time-invariant): 359276
# # rows    (time-dependent): 0
#
# --------------------------------------------------------------------------------
# 2-A) Transform time-invariant data
# --------------------------------------------------------------------------------
# (N × ^d) table            :	 (19723, 195)
# number of missing entries :	 3486709 out of 3845985 total
# Time elapsed: 3.429075 seconds
#
# Output
# s_all, binary features    :	 (19723, 195)
# Time elapsed: 10.619617 seconds
#
# --------------------------------------------------------------------------------
# 3-A) Post-filter time-invariant data
# --------------------------------------------------------------------------------
# Original       : 195
# Nearly-constant: 83
# Correlated     : 0
# Time elapsed: 10.685940 seconds
#
# Output
# s: shape=(19723, 112), density=0.161
# Total time: 10.819598 seconds

# %%
! PYTHONPATH="$PYTHONPATH:./" \
python -m FIDDLE_icd.run \
    --data_path='./output/' \
    --input_fname='./data/icd_data.csv' \
    --population='./input/pop.csv' \
    --T=4320.0 --dt=1.0 \
    --theta_1=0.01 --theta_2=0.01 --theta_freq=1
# [0,1,2]
# Out:
# Input data file: ./data/icd_data.csv
#
# Input arguments:
#     T      = 4320
#     dt     = 1.0
#     θ₁     = 0.01
#     θ₂     = 0.01
#     θ_freq = 1.0
#     k      = 3 ['min', 'max', 'mean']
# binarize = yes
#
# N = 19723
# L = 4320
#
#
# ================================================================================
# 1) Pre-filter
# ================================================================================
# Remove rows not in population
# Remove rows with t outside of [0, 4320]
# Remove rare variables (<= 0.01)
# Total variables     : 1
# Rare variables      : 0
# Remaining variables : 1
# # rows (original)   : 280540
# # rows (filtered)   : 280540
#
# ================================================================================
# 2) Transform; 3) Post-filter
# ================================================================================
#
# --------------------------------------------------------------------------------
# *) Detecting and parsing value types
# --------------------------------------------------------------------------------
# Saved as: ./output/value_types.csv
# 2020-03-13 13:18:08,557: Note: detected 112 virtual cores but NumExpr set to maximum of 64, check "NUMEXPR_MAX_THREADS" environment variable.
# 2020-03-13 13:18:08,557: Note: NumExpr detected 112 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 2020-03-13 13:18:08,558: NumExpr defaulting to 8 threads.
#
# --------------------------------------------------------------------------------
# *) Separate time-invariant and time-dependent
# --------------------------------------------------------------------------------
# Variables (time-invariant): 1284
# Variables (time-dependent): 0
# # rows    (time-invariant): 615416
# # rows    (time-dependent): 0
#
# --------------------------------------------------------------------------------
# 2-A) Transform time-invariant data
# --------------------------------------------------------------------------------
# (N × ^d) table            :	 (19723, 1284)
# number of missing entries :	 24708916 out of 25324332 total
# Time elapsed: 2.677823 seconds
#
# Output
# s_all, binary features    :	 (19723, 1284)
# Time elapsed: 51.262696 seconds
#
# --------------------------------------------------------------------------------
# 3-A) Post-filter time-invariant data
# --------------------------------------------------------------------------------
# Original       : 1284
# Nearly-constant: 965
# Correlated     : 5
# Time elapsed: 51.485347 seconds
#
# Output
# s: shape=(19723, 314), density=0.094
# Total time: 51.716304 seconds

# %% [markdown]
# ## Run FIDDLE

# %%
! PYTHONPATH="$PYTHONPATH:./" \
python -m FIDDLE_icd.run \
    --data_path='./output_clinical/' \
    --input_fname='./data/clinical.p' \
    --population='./input/pop.csv' \
    --T=4320.0 --dt=4320.0 \
    --theta_1=0.01 --theta_2=0.01 --theta_freq=1
# Out:
# Input data file: ./data/clinical.p
#
# Input arguments:
#     T      = 4320
#     dt     = 4320.0
#     θ₁     = 0.01
#     θ₂     = 0.01
#     θ_freq = 1.0
#     k      = 3 ['min', 'max', 'mean']
# binarize = yes
#
# N = 19723
# L = 1
#
#
# ================================================================================
# 1) Pre-filter
# ================================================================================
# Remove rows not in population
# Remove rows with t outside of [0, 4320]
# Remove rare variables (<= 0.01)
# Total variables     : 4836
# Rare variables      : 2941
# Remaining variables : 1895
# # rows (original)   : 112592300
# # rows (filtered)   : 111280602
#
# ================================================================================
# 2) Transform; 3) Post-filter
# ================================================================================
#
# --------------------------------------------------------------------------------
# *) Detecting and parsing value types
# --------------------------------------------------------------------------------
# Saved as: ./output_clinical/value_types.csv
# 2020-03-13 13:48:16,136: Note: detected 112 virtual cores but NumExpr set to maximum of 64, check "NUMEXPR_MAX_THREADS" environment variable.
# 2020-03-13 13:48:16,136: Note: NumExpr detected 112 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 2020-03-13 13:48:16,136: NumExpr defaulting to 8 threads.
#
# --------------------------------------------------------------------------------
# *) Separate time-invariant and time-dependent
# --------------------------------------------------------------------------------
# Variables (time-invariant): 0
# Variables (time-dependent): 1895
# # rows    (time-invariant): 0
# # rows    (time-dependent): 111280602
#
# --------------------------------------------------------------------------------
# 2-B) Transform time-dependent data
# --------------------------------------------------------------------------------
# Total variables    : 1895
# Frequent variables : ['220046', '220047', '220048', '220048: 1st AV (First degree AV Block) ', '220048: A Paced', '220048: AF (Atrial Fibrillation)', '220048: AV Paced', '220048: SB (Sinus Bradycardia)', '220048: SR (Sinus Rhythm)', '220048: ST (Sinus Tachycardia) ', '220048: V Paced', '220052', '220056', '220058', '220059', '220060', '220061', '220072', '220073', '220074', '220181', '220292', '220293', '220339', '220765', '223751', '223752', '223769', '223770', '223772', '223773', '223780', '223780: